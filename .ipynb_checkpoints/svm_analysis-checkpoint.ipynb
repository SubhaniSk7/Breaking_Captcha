# %%
import glob
from sklearn.svm import SVC
from sklearn.externals import joblib
import numpy as np
from skimage import io

from sklearn.metrics import accuracy_score,f1_score,classification_report

# %%
My_SVM = joblib.load('SVM.sav')
# Out:
# /home/dhruv/anaconda3/lib/python3.6/site-packages/sklearn/base.py:251: UserWarning: Trying to unpickle estimator SVC from version 0.20.1 when using version 0.20.0. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
def normalise(l):
    ret = []
    c = len(l)
    for i in range(c):
        for j in range(c):
            ret.append(l[i][j])
    return np.array(ret)

# %%
def get_predicted_value_and_score_for_single_image(img_folder_location):
    label = img_folder_location.split('/')[-1][0]
    image = io.imread(img_folder_location + "/Char0.jpg")
    normalised_img = normalise(image)
    ls_i = np.array([normalised_img])
    v = My_SVM.predict(ls_i)
    print("ground truth : " + label + "   predicted value : " + chr(v+65))
    if(label != chr(v+65)):
        print('-----------------------')
    return label, chr(v+65)

# %%
def get_scores_for_all_test_images():
    file_paths = []
    y_actual=[]
    y_predicted=[]
    for path in glob.glob("./Test1char/*"):
        ground_truth,predicted_value = get_predicted_value_and_score_for_single_image(path)
        y_actual.append(ground_truth)
        y_predicted.append(predicted_value)
    
    print(accuracy_score(y_actual,y_predicted))
    print('f1_score:',f1_score(y_actual,y_predicted,average='macro'))
    print('f1_score:',f1_score(y_actual,y_predicted,average='micro'))
    print('f1_score:',f1_score(y_actual,y_predicted,average='weighted'))
    print('f1_score:',f1_score(y_actual,y_predicted,average=None))
    print(classification_report(y_actual, y_predicted))
    
    
get_scores_for_all_test_images()
# Out:
# ground truth : G   predicted value : G
# ground truth : Z   predicted value : Z
# ground truth : C   predicted value : C
# ground truth : U   predicted value : U
# ground truth : X   predicted value : X
# ground truth : C   predicted value : C
# ground truth : S   predicted value : S
# ground truth : R   predicted value : R
# ground truth : Y   predicted value : Y
# ground truth : V   predicted value : V
# ground truth : D   predicted value : D
# ground truth : P   predicted value : P
# ground truth : B   predicted value : B
# ground truth : L   predicted value : L
# ground truth : B   predicted value : B
# ground truth : N   predicted value : N
# ground truth : K   predicted value : K
# ground truth : I   predicted value : I
# ground truth : Y   predicted value : Y
# ground truth : V   predicted value : V
# ground truth : B   predicted value : B
# ground truth : A   predicted value : A
# ground truth : E   predicted value : E
# ground truth : C   predicted value : C
# ground truth : M   predicted value : M
# ground truth : R   predicted value : R
# ground truth : G   predicted value : G
# ground truth : R   predicted value : R
# ground truth : Y   predicted value : Y
# ground truth : S   predicted value : S
# ground truth : W   predicted value : W
# ground truth : L   predicted value : L
# ground truth : M   predicted value : M
# ground truth : D   predicted value : D
# ground truth : B   predicted value : B
# ground truth : M   predicted value : M
# ground truth : W   predicted value : W
# ground truth : L   predicted value : L
# ground truth : F   predicted value : F
# ground truth : T   predicted value : T
# ground truth : P   predicted value : P
# ground truth : S   predicted value : S
# ground truth : R   predicted value : R
# ground truth : J   predicted value : J
# ground truth : H   predicted value : H
# ground truth : M   predicted value : M
# ground truth : B   predicted value : B
# ground truth : R   predicted value : R
# ground truth : U   predicted value : U
# ground truth : N   predicted value : G
# -----------------------
# ground truth : R   predicted value : R
# ground truth : F   predicted value : F
# ground truth : N   predicted value : N
# ground truth : C   predicted value : C
# ground truth : U   predicted value : U
# ground truth : C   predicted value : C
# ground truth : C   predicted value : C
# ground truth : G   predicted value : G
# ground truth : J   predicted value : J
# ground truth : U   predicted value : U
# ground truth : A   predicted value : A
# ground truth : Z   predicted value : Z
# ground truth : O   predicted value : O
# ground truth : K   predicted value : K
# ground truth : S   predicted value : S
# ground truth : G   predicted value : G
# ground truth : A   predicted value : A
# ground truth : J   predicted value : J
# ground truth : R   predicted value : R
# ground truth : U   predicted value : U
# ground truth : E   predicted value : E
# ground truth : V   predicted value : V
# ground truth : F   predicted value : F
# ground truth : M   predicted value : M
# ground truth : A   predicted value : A
# ground truth : Y   predicted value : Y
# ground truth : K   predicted value : K
# ground truth : X   predicted value : X
# ground truth : R   predicted value : R
# ground truth : D   predicted value : D
# ground truth : F   predicted value : F
# ground truth : B   predicted value : B
# ground truth : T   predicted value : T
# ground truth : H   predicted value : H
# ground truth : I   predicted value : I
# ground truth : A   predicted value : A
# ground truth : W   predicted value : W
# ground truth : U   predicted value : U
# ground truth : M   predicted value : M
# ground truth : D   predicted value : D
# ground truth : J   predicted value : J
# ground truth : W   predicted value : W
# ground truth : D   predicted value : D
# ground truth : V   predicted value : V
# ground truth : U   predicted value : U
# ground truth : Q   predicted value : Q
# ground truth : W   predicted value : W
# ground truth : W   predicted value : W
# ground truth : P   predicted value : P
# ground truth : Z   predicted value : Z
# ground truth : G   predicted value : G
# ground truth : H   predicted value : H
# ground truth : Z   predicted value : Z
# ground truth : K   predicted value : K
# ground truth : G   predicted value : G
# ground truth : J   predicted value : J
# ground truth : P   predicted value : P
# ground truth : C   predicted value : C
# ground truth : U   predicted value : U
# ground truth : V   predicted value : V
# ground truth : Z   predicted value : Z
# ground truth : V   predicted value : V
# ground truth : W   predicted value : W
# ground truth : M   predicted value : M
# ground truth : X   predicted value : X
# ground truth : A   predicted value : A
# ground truth : V   predicted value : V
# ground truth : F   predicted value : F
# ground truth : B   predicted value : B
# ground truth : O   predicted value : O
# ground truth : N   predicted value : N
# ground truth : B   predicted value : B
# ground truth : R   predicted value : R
# ground truth : K   predicted value : K
# ground truth : Z   predicted value : Z
# ground truth : A   predicted value : A
# ground truth : B   predicted value : B
# ground truth : J   predicted value : J
# ground truth : W   predicted value : W
# ground truth : Z   predicted value : Z
# ground truth : H   predicted value : H
# ground truth : Y   predicted value : Y
# ground truth : L   predicted value : L
# ground truth : M   predicted value : M
# ground truth : A   predicted value : A
# ground truth : K   predicted value : K
# ground truth : T   predicted value : T
# ground truth : H   predicted value : H
# ground truth : E   predicted value : E
# ground truth : Y   predicted value : Y
# ground truth : B   predicted value : B
# ground truth : I   predicted value : I
# ground truth : P   predicted value : P
# ground truth : J   predicted value : J
# ground truth : X   predicted value : X
# ground truth : F   predicted value : F
# ground truth : A   predicted value : A
# ground truth : K   predicted value : K
# ground truth : K   predicted value : K
# ground truth : J   predicted value : J
# ground truth : Z   predicted value : Z
# ground truth : R   predicted value : R
# ground truth : O   predicted value : O
# ground truth : P   predicted value : P
# ground truth : K   predicted value : K
# ground truth : Z   predicted value : Z
# ground truth : F   predicted value : F
# ground truth : R   predicted value : R
# ground truth : O   predicted value : O
# ground truth : P   predicted value : P
# ground truth : V   predicted value : V
# ground truth : W   predicted value : W
# ground truth : U   predicted value : U
# ground truth : B   predicted value : B
# ground truth : X   predicted value : X
# ground truth : B   predicted value : B
# ground truth : S   predicted value : S
# ground truth : R   predicted value : R
# ground truth : I   predicted value : I
# ground truth : F   predicted value : F
# ground truth : W   predicted value : W
# ground truth : Q   predicted value : Q
# ground truth : X   predicted value : X
# ground truth : G   predicted value : G
# ground truth : O   predicted value : O
# ground truth : L   predicted value : L
# ground truth : S   predicted value : S
# ground truth : H   predicted value : H
# ground truth : R   predicted value : R
# ground truth : W   predicted value : W
# ground truth : R   predicted value : R
# ground truth : Z   predicted value : Z
# ground truth : H   predicted value : H
# ground truth : I   predicted value : I
# ground truth : Z   predicted value : Z
# ground truth : M   predicted value : M
# ground truth : J   predicted value : J
# ground truth : W   predicted value : W
# ground truth : S   predicted value : S
# ground truth : B   predicted value : B
# ground truth : T   predicted value : T
# ground truth : V   predicted value : V
# ground truth : N   predicted value : N
# ground truth : J   predicted value : J
# ground truth : J   predicted value : J
# ground truth : Z   predicted value : Z
# ground truth : V   predicted value : V
# ground truth : H   predicted value : H
# ground truth : M   predicted value : M
# ground truth : F   predicted value : F
# ground truth : D   predicted value : D
# ground truth : S   predicted value : S
# ground truth : X   predicted value : X
# ground truth : H   predicted value : H
# ground truth : N   predicted value : N
# ground truth : F   predicted value : F
# ground truth : U   predicted value : U
# ground truth : E   predicted value : E
# ground truth : N   predicted value : N
# ground truth : D   predicted value : D
# ground truth : W   predicted value : W
# ground truth : W   predicted value : W
# ground truth : V   predicted value : V
# ground truth : G   predicted value : G
# ground truth : J   predicted value : J
# ground truth : G   predicted value : G
# ground truth : F   predicted value : F
# ground truth : R   predicted value : R
# ground truth : L   predicted value : L
# ground truth : S   predicted value : S
# ground truth : D   predicted value : D
# ground truth : Z   predicted value : Z
# ground truth : K   predicted value : K
# ground truth : O   predicted value : O
# ground truth : J   predicted value : J
# ground truth : S   predicted value : S
# ground truth : B   predicted value : B
# ground truth : Y   predicted value : Y
# ground truth : T   predicted value : T
# ground truth : U   predicted value : U
# ground truth : R   predicted value : R
# ground truth : I   predicted value : I
# ground truth : J   predicted value : J
# ground truth : F   predicted value : F
# ground truth : I   predicted value : I
# ground truth : T   predicted value : T
# ground truth : E   predicted value : E
# ground truth : U   predicted value : U
# ground truth : B   predicted value : B
# ground truth : Y   predicted value : Y
# ground truth : P   predicted value : P
# ground truth : Z   predicted value : Z
# ground truth : T   predicted value : T
# ground truth : Y   predicted value : Y
# ground truth : E   predicted value : E
# ground truth : O   predicted value : O
# ground truth : U   predicted value : U
# ground truth : K   predicted value : K
# ground truth : X   predicted value : X
# ground truth : R   predicted value : R
# ground truth : B   predicted value : B
# ground truth : D   predicted value : D
# ground truth : Y   predicted value : Y
# ground truth : A   predicted value : A
# ground truth : G   predicted value : G
# ground truth : T   predicted value : T
# ground truth : A   predicted value : A
# ground truth : S   predicted value : S
# ground truth : N   predicted value : N
# ground truth : D   predicted value : D
# ground truth : V   predicted value : V
# ground truth : Q   predicted value : Q
# ground truth : E   predicted value : E
# ground truth : X   predicted value : X
# ground truth : I   predicted value : I
# ground truth : X   predicted value : X
# ground truth : I   predicted value : I
# ground truth : A   predicted value : A
# ground truth : U   predicted value : U
# ground truth : D   predicted value : D
# ground truth : X   predicted value : X
# ground truth : N   predicted value : N
# ground truth : V   predicted value : V
# ground truth : M   predicted value : M
# ground truth : L   predicted value : L
# ground truth : Z   predicted value : Z
# ground truth : W   predicted value : W
# ground truth : L   predicted value : L
# ground truth : A   predicted value : A
# ground truth : Y   predicted value : Y
# ground truth : Q   predicted value : Q
# ground truth : D   predicted value : D
# ground truth : A   predicted value : A
# ground truth : X   predicted value : X
# ground truth : S   predicted value : S
# ground truth : J   predicted value : J
# ground truth : Y   predicted value : Y
# ground truth : Y   predicted value : Y
# ground truth : V   predicted value : V
# ground truth : D   predicted value : D
# ground truth : F   predicted value : F
# ground truth : T   predicted value : T
# ground truth : A   predicted value : A
# ground truth : B   predicted value : B
# ground truth : J   predicted value : J
# ground truth : H   predicted value : H
# ground truth : T   predicted value : T
# ground truth : S   predicted value : S
# ground truth : G   predicted value : G
# ground truth : B   predicted value : B
# ground truth : D   predicted value : D
# ground truth : D   predicted value : D
# ground truth : I   predicted value : I
# ground truth : N   predicted value : N
# ground truth : R   predicted value : R
# ground truth : P   predicted value : P
# ground truth : H   predicted value : H
# ground truth : G   predicted value : G
# ground truth : L   predicted value : L
# ground truth : I   predicted value : I
# ground truth : I   predicted value : I
# ground truth : W   predicted value : W
# ground truth : B   predicted value : B
# ground truth : Y   predicted value : Y
# ground truth : V   predicted value : V
# ground truth : L   predicted value : L
# ground truth : C   predicted value : C
# ground truth : L   predicted value : L
# ground truth : T   predicted value : T
# ground truth : J   predicted value : J
# ground truth : T   predicted value : T
# ground truth : O   predicted value : O
# ground truth : A   predicted value : A
# ground truth : C   predicted value : C
# ground truth : Y   predicted value : Y
# ground truth : O   predicted value : T
# -----------------------
# ground truth : H   predicted value : H
# ground truth : Q   predicted value : Q
# ground truth : B   predicted value : B
# ground truth : D   predicted value : D
# ground truth : U   predicted value : U
# ground truth : Z   predicted value : Z
# ground truth : N   predicted value : N
# ground truth : I   predicted value : I
# ground truth : T   predicted value : T
# ground truth : A   predicted value : A
# ground truth : T   predicted value : T
# ground truth : H   predicted value : H
# ground truth : E   predicted value : E
# ground truth : G   predicted value : G
# ground truth : V   predicted value : V
# ground truth : D   predicted value : D
# ground truth : O   predicted value : O
# ground truth : A   predicted value : A
# ground truth : D   predicted value : D
# ground truth : F   predicted value : F
# ground truth : W   predicted value : W
# ground truth : E   predicted value : E
# ground truth : O   predicted value : O
# ground truth : W   predicted value : W
# ground truth : Z   predicted value : Z
# ground truth : R   predicted value : R
# ground truth : T   predicted value : T
# ground truth : Z   predicted value : Z
# ground truth : H   predicted value : H
# ground truth : A   predicted value : A
# ground truth : O   predicted value : O
# ground truth : P   predicted value : P
# ground truth : W   predicted value : W
# ground truth : Y   predicted value : Y
# ground truth : F   predicted value : F
# ground truth : A   predicted value : A
# ground truth : V   predicted value : V
# ground truth : M   predicted value : M
# ground truth : S   predicted value : S
# ground truth : Z   predicted value : Z
# ground truth : C   predicted value : C
# ground truth : E   predicted value : E
# ground truth : V   predicted value : V
# ground truth : D   predicted value : D
# ground truth : O   predicted value : O
# ground truth : Q   predicted value : Q
# ground truth : X   predicted value : X
# ground truth : N   predicted value : N
# ground truth : N   predicted value : N
# ground truth : K   predicted value : K
# ground truth : Y   predicted value : Y
# ground truth : P   predicted value : P
# ground truth : R   predicted value : R
# ground truth : V   predicted value : V
# ground truth : U   predicted value : U
# ground truth : C   predicted value : C
# ground truth : R   predicted value : R
# ground truth : P   predicted value : P
# ground truth : V   predicted value : V
# ground truth : F   predicted value : F
# ground truth : U   predicted value : U
# ground truth : W   predicted value : W
# ground truth : X   predicted value : X
# ground truth : W   predicted value : W
# ground truth : E   predicted value : E
# ground truth : J   predicted value : J
# ground truth : J   predicted value : J
# ground truth : Z   predicted value : Z
# ground truth : R   predicted value : R
# ground truth : F   predicted value : F
# ground truth : Y   predicted value : Y
# ground truth : X   predicted value : X
# ground truth : L   predicted value : L
# ground truth : I   predicted value : I
# ground truth : U   predicted value : U
# ground truth : X   predicted value : X
# ground truth : W   predicted value : W
# ground truth : E   predicted value : E
# ground truth : L   predicted value : L
# ground truth : M   predicted value : M
# ground truth : X   predicted value : X
# ground truth : G   predicted value : G
# ground truth : X   predicted value : X
# ground truth : G   predicted value : G
# ground truth : T   predicted value : T
# ground truth : Q   predicted value : Q
# ground truth : H   predicted value : H
# ground truth : N   predicted value : N
# ground truth : F   predicted value : F
# ground truth : C   predicted value : C
# ground truth : Y   predicted value : Y
# ground truth : Q   predicted value : Q
# ground truth : Q   predicted value : Q
# ground truth : O   predicted value : O
# ground truth : C   predicted value : C
# ground truth : G   predicted value : G
# ground truth : V   predicted value : V
# ground truth : U   predicted value : U
# ground truth : O   predicted value : O
# ground truth : N   predicted value : N
# ground truth : J   predicted value : J
# ground truth : C   predicted value : C
# ground truth : R   predicted value : R
# ground truth : Z   predicted value : Z
# ground truth : N   predicted value : N
# ground truth : A   predicted value : A
# ground truth : N   predicted value : N
# ground truth : B   predicted value : B
# ground truth : F   predicted value : F
# ground truth : C   predicted value : C
# ground truth : M   predicted value : M
# ground truth : W   predicted value : W
# ground truth : F   predicted value : F
# ground truth : B   predicted value : B
# ground truth : S   predicted value : S
# ground truth : J   predicted value : J
# ground truth : C   predicted value : C
# ground truth : O   predicted value : O
# ground truth : R   predicted value : R
# ground truth : X   predicted value : X
# ground truth : B   predicted value : B
# ground truth : M   predicted value : M
# ground truth : D   predicted value : D
# ground truth : H   predicted value : H
# ground truth : D   predicted value : D
# ground truth : D   predicted value : D
# ground truth : W   predicted value : W
# ground truth : H   predicted value : H
# ground truth : R   predicted value : R
# ground truth : R   predicted value : R
# ground truth : M   predicted value : M
# ground truth : W   predicted value : W
# ground truth : V   predicted value : V
# ground truth : V   predicted value : V
# ground truth : D   predicted value : D
# ground truth : Q   predicted value : Q
# ground truth : G   predicted value : G
# ground truth : P   predicted value : P
# ground truth : M   predicted value : M
# ground truth : Q   predicted value : Q
# ground truth : Z   predicted value : Z
# ground truth : Z   predicted value : Z
# ground truth : Y   predicted value : Y
# ground truth : B   predicted value : B
# ground truth : R   predicted value : R
# ground truth : D   predicted value : D
# ground truth : S   predicted value : S
# ground truth : P   predicted value : P
# ground truth : E   predicted value : E
# ground truth : C   predicted value : C
# ground truth : K   predicted value : K
# ground truth : B   predicted value : B
# ground truth : O   predicted value : O
# ground truth : G   predicted value : G
# ground truth : H   predicted value : H
# ground truth : P   predicted value : P
# ground truth : U   predicted value : U
# ground truth : C   predicted value : C
# ground truth : D   predicted value : D
# ground truth : D   predicted value : D
# ground truth : J   predicted value : J
# ground truth : R   predicted value : R
# ground truth : B   predicted value : B
# ground truth : F   predicted value : F
# ground truth : D   predicted value : D
# ground truth : L   predicted value : L
# ground truth : A   predicted value : A
# ground truth : H   predicted value : H
# ground truth : B   predicted value : B
# ground truth : T   predicted value : T
# ground truth : T   predicted value : T
# ground truth : I   predicted value : I
# ground truth : J   predicted value : J
# ground truth : D   predicted value : D
# ground truth : D   predicted value : D
# ground truth : A   predicted value : A
# ground truth : Z   predicted value : Z
# ground truth : T   predicted value : T
# ground truth : X   predicted value : X
# ground truth : O   predicted value : O
# ground truth : I   predicted value : I
# ground truth : Z   predicted value : Z
# ground truth : V   predicted value : V
# ground truth : R   predicted value : R
# ground truth : L   predicted value : L
# ground truth : J   predicted value : J
# ground truth : R   predicted value : R
# ground truth : O   predicted value : O
# ground truth : M   predicted value : M
# ground truth : N   predicted value : N
# ground truth : R   predicted value : R
# ground truth : K   predicted value : K
# ground truth : Q   predicted value : Q
# ground truth : N   predicted value : N
# ground truth : H   predicted value : H
# ground truth : Z   predicted value : Z
# ground truth : E   predicted value : E
# ground truth : N   predicted value : N
# ground truth : Z   predicted value : Z
# ground truth : H   predicted value : H
# 0.9961977186311787
# f1_score: 0.9959486113332267
# f1_score: 0.9961977186311787
# f1_score: 0.9961977186311787
# f1_score: [1.         1.         1.         1.         1.         1.
#  0.97297297 1.         1.         1.         1.         1.
#  1.         0.97435897 0.97297297 1.         1.         1.
#  1.         0.97435897 1.         1.         1.         1.
#  1.         1.        ]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-cf475afc93d5> in <module>()
#      16
#      17
# ---> 18 get_scores_for_all_test_images()
#
# <ipython-input-72-cf475afc93d5> in get_scores_for_all_test_images()
#      13     print('f1_score:',f1_score(y_actual,y_predicted,average='weighted'))
#      14     print('f1_score:',f1_score(y_actual,y_predicted,average=None))
# ---> 15     print(classification_report(y_actual, y_predicted, target_names=y_actual))
#      16
#      17
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict)
#    1541                 "Number of classes, {0}, does not match size of "
#    1542                 "target_names, {1}. Try specifying the labels "
# -> 1543                 "parameter".format(len(labels), len(target_names))
#    1544             )
#    1545     if target_names is None:
#
# ValueError: Number of classes, 26, does not match size of target_names, 526. Try specifying the labels parameter
